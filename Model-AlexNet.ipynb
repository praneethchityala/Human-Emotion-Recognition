# %% [markdown]
# ## Importing Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,accuracy_score
from scipy import stats

from tensorflow.keras.preprocessing.image import load_img, img_to_array,ImageDataGenerator
from tensorflow.keras.layers import Dense,Input,Dropout,GlobalAveragePooling2D,Flatten,Conv2D,BatchNormalization,Activation,MaxPooling2D,AveragePooling2D
from tensorflow.keras.models import Model,Sequential,load_model
from tensorflow.keras.optimizers import Adam,SGD,RMSprop
from tensorflow.keras.callbacks import TensorBoard,ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
# Out:
# Init Plugin
# Init Graph Optimizer
# Init Kernel

# %% [markdown]
# ## Displaying Images

# %%
picture_size = 48
folder_path = "/Users/praneeth44/OneDrive - Indiana University/IU/AML/Project/FER 2013/archive/"

# %% [markdown]
# ## Making Training and Validation Data

# %%
batch_size  = 100

datagen_train  = ImageDataGenerator()
datagen_val = ImageDataGenerator()

train_set = datagen_train.flow_from_directory(folder_path+"train",
                                              target_size = (picture_size,picture_size),
                                              color_mode = "grayscale",
                                              batch_size=batch_size,
                                              class_mode='categorical',
                                              shuffle=True)


test_set = datagen_val.flow_from_directory(folder_path+"test",
                                              target_size = (picture_size,picture_size),
                                              color_mode = "grayscale",
                                              batch_size=batch_size,
                                              class_mode='categorical',
                                              shuffle=True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# ## Model Building

# %%
no_of_classes = 7

AlexNet = Sequential()

#1st CNN layer
AlexNet.add(Conv2D(96,11,strides=1,input_shape = (48,48,1)))
# AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size = (3,2)))
# AlexNet.add(Dropout(0.25))

#2nd CNN layer
AlexNet.add(Conv2D(256,5,strides=1,padding = 'same'))
# AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size = (3,2)))
# AlexNet.add(Dropout (0.25))

#3rd CNN layer
AlexNet.add(Conv2D(384,3,strides=1,padding = 'same'))
# AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size = (3,2)))
# AlexNet.add(Dropout (0.25))

#4th CNN layer
AlexNet.add(Conv2D(256,3,strides=1,padding = 'same'))
# AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
# AlexNet.add(MaxPooling2D(pool_size=(3, 2)))
# AlexNet.add(Dropout(0.25))

AlexNet.add(Flatten())

#Fully connected 1st layer
AlexNet.add(Dense(4096))
# AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(Dropout(0.5))

#Fully connected 2nd layer
AlexNet.add(Dense(4096))
# AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(Dropout(0.5))


# # Fully connected 3rd layer
# AlexNet.add(Dense(512))
# AlexNet.add(BatchNormalization())
# AlexNet.add(Activation('relu'))
# AlexNet.add(Dropout(0.25))

AlexNet.add(Dense(no_of_classes, activation='softmax'))



opt = SGD(lr = 0.0001)
AlexNet.compile(optimizer=opt,loss='categorical_crossentropy', metrics=['accuracy'])
AlexNet.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_30 (Conv2D)           (None, 38, 38, 96)        11712
# _________________________________________________________________
# activation_36 (Activation)   (None, 38, 38, 96)        0
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 12, 19, 96)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 12, 19, 256)       614656
# _________________________________________________________________
# activation_37 (Activation)   (None, 12, 19, 256)       0
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 4, 9, 256)         0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 4, 9, 384)         885120
# _________________________________________________________________
# activation_38 (Activation)   (None, 4, 9, 384)         0
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 1, 4, 384)         0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 1, 4, 256)         884992
# _________________________________________________________________
# activation_39 (Activation)   (None, 1, 4, 256)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 4096)              4198400
# _________________________________________________________________
# activation_40 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 4096)              16781312
# _________________________________________________________________
# activation_41 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 7)                 28679
# =================================================================
# Total params: 23,404,871
# Trainable params: 23,404,871
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Fitting the Model with Training and Validation Data

# %%
checkpoint = ModelCheckpoint(filepath="/Users/praneeth44/OneDrive - Indiana University/IU/AML/Project/FER 2013/archive/AlexNet.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

early_stopping = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=20,
                          verbose=1,
                          restore_best_weights=True
                          )

reduce_learningrate = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=3,
                              verbose=1,
                              min_delta=0.0001)

callbacks_list = [early_stopping,checkpoint,reduce_learningrate]

epochs = 100

AlexNet.compile(loss='categorical_crossentropy',
              optimizer = Adam(lr=0.001),
              metrics=['accuracy'])

# %%
history = AlexNet.fit_generator(generator=train_set,
                                steps_per_epoch=train_set.n//train_set.batch_size,
                                epochs=epochs,
                                validation_data = test_set,
                                validation_steps = test_set.n//test_set.batch_size,
                                callbacks=callbacks_list
                                )
# Out:
# Epoch 1/100
# 2021-12-14 11:49:27.888639: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 287/287 [==============================] - ETA: 0s - loss: 2.0641 - accuracy: 0.2719
# 2021-12-14 11:50:20.498165: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 287/287 [==============================] - 56s 194ms/step - loss: 2.0641 - accuracy: 0.2719 - val_loss: 1.6689 - val_accuracy: 0.3315
#
# Epoch 00001: val_accuracy improved from -inf to 0.33155, saving model to /Users/praneeth44/OneDrive - Indiana University/IU/AML/Project/FER 2013/archive/AlexNet.h5
# Epoch 2/100
# 287/287 [==============================] - 56s 193ms/step - loss: 1.6541 - accuracy: 0.3437 - val_loss: 1.5858 - val_accuracy: 0.3835
#
# Epoch 00002: val_accuracy improved from 0.33155 to 0.38352, saving model to /Users/praneeth44/OneDrive - Indiana University/IU/AML/Project/FER 2013/archive/AlexNet.h5
# Epoch 3/100
# 287/287 [==============================] - 55s 190ms/step - loss: 1.5632 - accuracy: 0.3868 - val_loss: 1.5322 - val_accuracy: 0.3989
#
# Epoch 00003: val_accuracy improved from 0.38352 to 0.39887, saving model to /Users/praneeth44/OneDrive - Indiana University/IU/AML/Project/FER 2013/archive/AlexNet.h5
# Epoch 4/100
# 287/287 [==============================] - 55s 191ms/step - loss: 1.5121 - accuracy: 0.4116 - val_loss: 1.5165 - val_accuracy: 0.4039
#
# Epoch 00004: val_accuracy improved from 0.39887 to 0.40394, saving model to /Users/praneeth44/OneDrive - Indiana University/IU/AML/Project/FER 2013/archive/AlexNet.h5
# Epoch 5/100
# 287/287 [==============================] - 55s 191ms/step - loss: 1.4669 - accuracy: 0.4304 - val_loss: 1.4442 - val_accuracy: 0.4385
#
# Epoch 00005: val_accuracy improved from 0.40394 to 0.43845, saving model to /Users/praneeth44/OneDrive - Indiana University/IU/AML/Project/FER 2013/archive/AlexNet.h5
# Epoch 6/100
# 287/287 [==============================] - 55s 189ms/step - loss: 1.4286 - accuracy: 0.4464 - val_loss: 1.4379 - val_accuracy: 0.4335
#
# Epoch 00006: val_accuracy did not improve from 0.43845
# Epoch 7/100
# 287/287 [==============================] - 54s 189ms/step - loss: 1.4073 - accuracy: 0.4544 - val_loss: 1.4269 - val_accuracy: 0.4394
#
# Epoch 00007: val_accuracy improved from 0.43845 to 0.43944, saving model to /Users/praneeth44/OneDrive - Indiana University/IU/AML/Project/FER 2013/archive/AlexNet.h5
# Epoch 8/100
# 287/287 [==============================] - 55s 190ms/step - loss: 1.3685 - accuracy: 0.4717 - val_loss: 1.4162 - val_accuracy: 0.4565
#
# Epoch 00008: val_accuracy improved from 0.43944 to 0.45648, saving model to /Users/praneeth44/OneDrive - Indiana University/IU/AML/Project/FER 2013/archive/AlexNet.h5
# Epoch 9/100
# 287/287 [==============================] - 55s 189ms/step - loss: 1.3383 - accuracy: 0.4838 - val_loss: 1.4701 - val_accuracy: 0.4386
#
# Epoch 00009: val_accuracy did not improve from 0.45648
# Epoch 10/100
# 287/287 [==============================] - 54s 189ms/step - loss: 1.3025 - accuracy: 0.5034 - val_loss: 1.4093 - val_accuracy: 0.4451
#
# Epoch 00010: val_accuracy did not improve from 0.45648
# Epoch 11/100
# 287/287 [==============================] - 54s 189ms/step - loss: 1.2593 - accuracy: 0.5178 - val_loss: 1.4116 - val_accuracy: 0.4679
#
# Epoch 00011: val_accuracy improved from 0.45648 to 0.46789, saving model to /Users/praneeth44/OneDrive - Indiana University/IU/AML/Project/FER 2013/archive/AlexNet.h5
# Epoch 12/100
# 287/287 [==============================] - 55s 189ms/step - loss: 1.2431 - accuracy: 0.5262 - val_loss: 1.4254 - val_accuracy: 0.4632
#
# Epoch 00012: val_accuracy did not improve from 0.46789
# Epoch 13/100
# 287/287 [==============================] - 54s 189ms/step - loss: 1.2033 - accuracy: 0.5438 - val_loss: 1.4873 - val_accuracy: 0.4499
#
# Epoch 00013: val_accuracy did not improve from 0.46789
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 14/100
# 287/287 [==============================] - 54s 189ms/step - loss: 1.0199 - accuracy: 0.6134 - val_loss: 1.4314 - val_accuracy: 0.4866
#
# Epoch 00014: val_accuracy improved from 0.46789 to 0.48662, saving model to /Users/praneeth44/OneDrive - Indiana University/IU/AML/Project/FER 2013/archive/AlexNet.h5
# Epoch 15/100
# 287/287 [==============================] - 55s 189ms/step - loss: 0.9177 - accuracy: 0.6513 - val_loss: 1.4623 - val_accuracy: 0.4985
#
# Epoch 00015: val_accuracy improved from 0.48662 to 0.49845, saving model to /Users/praneeth44/OneDrive - Indiana University/IU/AML/Project/FER 2013/archive/AlexNet.h5
# Epoch 16/100
# 287/287 [==============================] - 56s 192ms/step - loss: 0.8501 - accuracy: 0.6797 - val_loss: 1.5108 - val_accuracy: 0.4965
#
# Epoch 00016: val_accuracy did not improve from 0.49845
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 17/100
# 287/287 [==============================] - 55s 192ms/step - loss: 0.7461 - accuracy: 0.7211 - val_loss: 1.5770 - val_accuracy: 0.4983
#
# Epoch 00017: val_accuracy did not improve from 0.49845
# Epoch 18/100
# 287/287 [==============================] - 55s 190ms/step - loss: 0.7159 - accuracy: 0.7332 - val_loss: 1.6307 - val_accuracy: 0.4966
#
# Epoch 00018: val_accuracy did not improve from 0.49845
# Epoch 19/100
# 287/287 [==============================] - 55s 191ms/step - loss: 0.6934 - accuracy: 0.7396 - val_loss: 1.6788 - val_accuracy: 0.4937
#
# Epoch 00019: val_accuracy did not improve from 0.49845
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 20/100
# 287/287 [==============================] - 55s 190ms/step - loss: 0.6661 - accuracy: 0.7533 - val_loss: 1.6834 - val_accuracy: 0.4952
#
# Epoch 00020: val_accuracy did not improve from 0.49845
# Epoch 21/100
# 287/287 [==============================] - 55s 190ms/step - loss: 0.6616 - accuracy: 0.7520 - val_loss: 1.6945 - val_accuracy: 0.4946
#
# Epoch 00021: val_accuracy did not improve from 0.49845
# Epoch 22/100
# 287/287 [==============================] - 55s 190ms/step - loss: 0.6556 - accuracy: 0.7572 - val_loss: 1.7009 - val_accuracy: 0.4963
#
# Epoch 00022: val_accuracy did not improve from 0.49845
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 23/100
# 287/287 [==============================] - 55s 191ms/step - loss: 0.6508 - accuracy: 0.7586 - val_loss: 1.7035 - val_accuracy: 0.4965
#
# Epoch 00023: val_accuracy did not improve from 0.49845
# Epoch 24/100
# 287/287 [==============================] - 61s 212ms/step - loss: 0.6468 - accuracy: 0.7592 - val_loss: 1.7146 - val_accuracy: 0.4951
#
# Epoch 00024: val_accuracy did not improve from 0.49845
# Epoch 25/100
# 287/287 [==============================] - 54s 190ms/step - loss: 0.6497 - accuracy: 0.7590 - val_loss: 1.7128 - val_accuracy: 0.4966
#
# Epoch 00025: val_accuracy did not improve from 0.49845
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 26/100
# 287/287 [==============================] - 55s 193ms/step - loss: 0.6458 - accuracy: 0.7605 - val_loss: 1.7175 - val_accuracy: 0.4956
#
# Epoch 00026: val_accuracy did not improve from 0.49845
# Epoch 27/100
# 287/287 [==============================] - 54s 190ms/step - loss: 0.6475 - accuracy: 0.7598 - val_loss: 1.7139 - val_accuracy: 0.4955
#
# Epoch 00027: val_accuracy did not improve from 0.49845
# Epoch 28/100
# 287/287 [==============================] - 54s 189ms/step - loss: 0.6470 - accuracy: 0.7587 - val_loss: 1.7152 - val_accuracy: 0.4955
#
# Epoch 00028: val_accuracy did not improve from 0.49845
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# Epoch 29/100
# 287/287 [==============================] - 55s 191ms/step - loss: 0.6450 - accuracy: 0.7594 - val_loss: 1.7161 - val_accuracy: 0.4945
#
# Epoch 00029: val_accuracy did not improve from 0.49845
# Epoch 30/100
# 287/287 [==============================] - 54s 190ms/step - loss: 0.6452 - accuracy: 0.7614 - val_loss: 1.7189 - val_accuracy: 0.4948
# Restoring model weights from the end of the best epoch.
#
# Epoch 00030: val_accuracy did not improve from 0.49845
# Epoch 00030: early stopping

# %% [markdown]
# ## Plotting Accuracy & Loss

# %%
plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## Tesing with total test data

# %%
emotion_labels = ['Angry','Disgust','Fear','Happy','Neutral', 'Sad', 'Surprise']

# %%
df = pd.read_csv('/Users/praneeth44/OneDrive - Indiana University/IU/AML/Project/FER 2013/fer2013_Modified.csv')
df
# Out:
#        emotion        Usage  p_1  p_2  p_3  p_4  p_5  p_6  p_7  p_8  ...  \
# 0            0     Training   70   80   82   72   58   58   60   63  ...
# 1            0     Training  151  150  147  155  148  133  111  140  ...
# 2            2     Training  231  212  156  164  174  138  161  173  ...
# 3            4     Training   24   32   36   30   32   23   19   20  ...
# 4            6     Training    4    0    0    0    0    0    0    0  ...
# ...        ...          ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 35882        6  PrivateTest   50   36   17   22   23   29   33   39  ...
# 35883        3  PrivateTest  178  174  172  173  181  188  191  194  ...
# 35884        0  PrivateTest   17   17   16   23   28   22   19   17  ...
# 35885        3  PrivateTest   30   28   28   29   31   30   42   68  ...
# 35886        2  PrivateTest   19   13   14   12   13   16   21   33  ...
#
#        p_2295  p_2296  p_2297  p_2298  p_2299  p_2300  p_2301  p_2302  p_2303  \
# 0         159     182     183     136     106     116      95     106     109
# 1         105     108      95     108     102      67     171     193     183
# 2         104     138     152     122     114     101      97      88     110
# 3         174     126     132     132     133     136     139     142     143
# 4          12      34      31      31      31      27      31      30      29
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 35882     216     215     216     217     221     222     220     223     221
# 35883     147     141     136     118      66       7       0       0       0
# 35884     190     179     193     193     194     170     148     154     133
# 35885      30      27      27      26      28      35      35      35      30
# 35886     224     217     209     195     151      99     146     189     199
#
#        p_2304
# 0          82
# 1         184
# 2         152
# 3         142
# 4          30
# ...       ...
# 35882     216
# 35883       0
# 35884     113
# 35885      28
# 35886     201
#
# [35887 rows x 2306 columns]

# %%
df_test=df[df['Usage'].isin(['PrivateTest'])].reset_index()
df_test
# Out:
#       index  emotion        Usage  p_1  p_2  p_3  p_4  p_5  p_6  p_7  ...  \
# 0     32298        0  PrivateTest  170  118  101   88   88   75   78  ...
# 1     32299        5  PrivateTest    7    5    8    6    7    3    2  ...
# 2     32300        6  PrivateTest  232  240  241  239  237  235  246  ...
# 3     32301        4  PrivateTest  200  197  149  139  156   89  111  ...
# 4     32302        2  PrivateTest   40   28   33   56   45   33   31  ...
# ...     ...      ...          ...  ...  ...  ...  ...  ...  ...  ...  ...
# 3584  35882        6  PrivateTest   50   36   17   22   23   29   33  ...
# 3585  35883        3  PrivateTest  178  174  172  173  181  188  191  ...
# 3586  35884        0  PrivateTest   17   17   16   23   28   22   19  ...
# 3587  35885        3  PrivateTest   30   28   28   29   31   30   42  ...
# 3588  35886        2  PrivateTest   19   13   14   12   13   16   21  ...
#
#       p_2295  p_2296  p_2297  p_2298  p_2299  p_2300  p_2301  p_2302  p_2303  \
# 0        210     210     222     222     204     190     174     159     133
# 1         41      37      76      88      84      88      82      72      57
# 2         64      21      89      68      46      67       2       4       4
# 3        142     161     185     185     107     146     144     149      33
# 4         25      26      29      26      28      25      24      24      29
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 3584     216     215     216     217     221     222     220     223     221
# 3585     147     141     136     118      66       7       0       0       0
# 3586     190     179     193     193     194     170     148     154     133
# 3587      30      27      27      26      28      35      35      35      30
# 3588     224     217     209     195     151      99     146     189     199
#
#       p_2304
# 0        131
# 1         52
# 2          9
# 3          0
# 4         26
# ...      ...
# 3584     216
# 3585       0
# 3586     113
# 3587      28
# 3588     201
#
# [3589 rows x 2307 columns]

# %%
y_true = df_test['emotion'].to_numpy()
y_true
# Out:
# array([0, 5, 6, ..., 0, 3, 2])

# %%
df_test_x = df_test.drop(['index','emotion','Usage'],axis=1)
df_test_x
# Out:
#       p_1  p_2  p_3  p_4  p_5  p_6  p_7  p_8  p_9  p_10  ...  p_2295  p_2296  \
# 0     170  118  101   88   88   75   78   82   66    74  ...     210     210
# 1       7    5    8    6    7    3    2    6    5     4  ...      41      37
# 2     232  240  241  239  237  235  246  117   24    24  ...      64      21
# 3     200  197  149  139  156   89  111   58   62    95  ...     142     161
# 4      40   28   33   56   45   33   31   78  152   194  ...      25      26
# ...   ...  ...  ...  ...  ...  ...  ...  ...  ...   ...  ...     ...     ...
# 3584   50   36   17   22   23   29   33   39   34    37  ...     216     215
# 3585  178  174  172  173  181  188  191  194  196   199  ...     147     141
# 3586   17   17   16   23   28   22   19   17   25    26  ...     190     179
# 3587   30   28   28   29   31   30   42   68   79    81  ...      30      27
# 3588   19   13   14   12   13   16   21   33   50    57  ...     224     217
#
#       p_2297  p_2298  p_2299  p_2300  p_2301  p_2302  p_2303  p_2304
# 0        222     222     204     190     174     159     133     131
# 1         76      88      84      88      82      72      57      52
# 2         89      68      46      67       2       4       4       9
# 3        185     185     107     146     144     149      33       0
# 4         29      26      28      25      24      24      29      26
# ...      ...     ...     ...     ...     ...     ...     ...     ...
# 3584     216     217     221     222     220     223     221     216
# 3585     136     118      66       7       0       0       0       0
# 3586     193     193     194     170     148     154     133     113
# 3587      27      26      28      35      35      35      30      28
# 3588     209     195     151      99     146     189     199     201
#
# [3589 rows x 2304 columns]

# %%
test = df_test_x.values.reshape(-1,48,48,1).astype('float32')

# %%
y_pred=AlexNet.predict(test).argmax(axis=1)

# %%
cm=confusion_matrix(y_true, y_pred)
cm
# Out:
# array([[251,   0,  32,  73,  65,  51,  19],
#        [ 43,   0,   1,   4,   2,   3,   2],
#        [151,   0,  75,  68,  71,  81,  82],
#        [ 86,   0,  21, 658,  48,  44,  22],
#        [171,   0,  23, 110, 126, 140,  24],
#        [ 31,   0,  35,  46,  30,  14, 260],
#        [155,   0,  19, 106, 252,  63,  31]])

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=emotion_labels)
disp.plot()
plt.figure(figsize=(20,10))
plt.show()

# %%
accuracy_score(y_true, y_pred)
# Out:
# 0.3218166620228476
